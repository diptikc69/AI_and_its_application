# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np

m1 = np.array([[5,10,15],[20,25,20]])
print(m1,"\n",m1.T)
print(np.eye(3))
# Out:
# [[ 5 10 15]
#  [20 25 20]]
#  [[ 5 20]
#  [10 25]
#  [15 20]]
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]

# %%
m1 = np.array([[2,1],[0,3]])
m2 = np.array([[1,2],[3,4]])

print(np.dot(m1,m2))
# Out:
# [[ 5  8]
#  [ 9 12]]

# %%
m1 = np.array([[0,1],[2,3]])
m2 = np.array([[4,5],[6,7]])

print(m1+m2)
# Out:
# [[ 4  6]
#  [ 8 10]]

# %%
vc = np.array([7,8,9])
print(2 * vc)

v1 = np.array([3,4])
v2 = np.array([1,2])

print(v1+v2)
print(v1-v2)
# Out:
# [14 16 18]
# [4 6]
# [2 2]
