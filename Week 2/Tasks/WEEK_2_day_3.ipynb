# %% [markdown]
# #Hands-On Practice: Probability Basics for AI

# %% [markdown]
# ##EXERCISE1 : THEORETICAL PROBABILITY

# %%
#Define total_outcome and favourable_outcome
total_outcome =6        #Sides of a die
favorable_outcome =  4  #Rolling a 6

probability =favorable_outcome / total_outcome
print("Probability of rolling a 6", probability)


#Task 1 : Calculate the theoretical probability of drawing a red card from a standard deck of 52 cards(26 red cards). Print the result.
# Out:
# Probability of rolling a 6 0.6666666666666666

# %% [markdown]
# ##Exercise 2 : Experimental Probability

# %%
import random

trails = 100
heads = 0

for _ in range(trails) :
  if random.choice(["Heads", "Trails"]) == "Heads" :
    heads+=1
    probability = heads/trails
print("Probability of getting Heads", probability)

#Task 2 : Simulate rolling a six-sided die 50 times and calculate the experimental probability
# Out:
# Probability of getting Heads 0.47

# %% [markdown]
# ##EXERCISE:3 CONDITIONAL PROBABILITY

# %%
red = 4
blue = 6
total = red + blue

# Not blue means only red balls
not_blue = red  # since the only balls that are not blue are red

# Probability that ball is red given it is not blue
P_red_given_not_blue = red / not_blue

print("Probability of getting a red ball given it is not blue is", P_red_given_not_blue)
# Out:
# Probability of getting a red ball given it is not blue is 1.0

# %%
#IN-CLASS TASK
#A standard deck has 52 cards. There are 12 face cards (Jack, Queen, King -4 of each).
#What is the probability that a card is a King given that it's a face card ?

#Out of 100 days, it rained on 30 days.
#On 25 of those rainy days, a person carried an umbrella.
#What is the probability that they carried an umbrella given that it was raining?

#Out of 80 students, 50 studied for the exam.
#Out of those 50,45 passed.
#What is the probability a student passed given that they studied ?

# total_cards = 52
# total_face_cards = 12
# king = 4

# king_cards = king / total_face_cards
# print("Probability of a king card is:", king_cards)


# rainy = 30
# umbrella_on_rainy = 25

# # P(Umbrella | Rain)
# P_umbrella_rain = umbrella_on_rainy / rainy

# print("Probability that the person carried an umbrella given that it was raining is", P_umbrella_rain)


# total_students = 80
# studied_for_the_exam = 50
# passed_students = 45

# total_prob_of_students = passed_students / studied_for_the_exam
# print(total_prob_of_students)
# Out:
# 0.9

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
total_balls = 100
total_yellow = 60
yellow_new = 40
yellow_old = 20


#case 1(when numbers are not given ) *

#probability that the ball is yellow
p_yellow = total_yellow / total_balls

#probability that the ball is new and yellow
p_new_yellow = yellow_new / total

#p(N|Y) = Probability that the ball is new given that its yellow
p_new_yellow_given_yellow = p_new_yellow / p_yellow
print("Probability that the ball is new given that it's yellow is", p_new_yellow_given_yellow)
# Out:
# Probability that the ball is new given that it's yellow is 6.666666666666667

# %% [markdown]
# #Exercise 4: Addition Rule

# %%
#Mutually exclusive events
prob_even = 3/6
prob_one= 1/6

prob_even_or_one = prob_even + prob_one
print("Probability of getting an even number or a 1 is", prob_even_or_one)


#Task 5: Calculate the probability of drawing a heart or a club from a deck(13 hearts, 13 clubs, mutually exclusive). Print the result.

PH = 13/53
PC = 13/52

PH_OR_PC = PH+PC
print(PH_OR_PC)
# Out:
# Probability of getting an even number or a 1 is 0.6666666666666666
# 0.49528301886792453

# %% [markdown]
# ##Exercise 5 : Multiplication Rule(Independent Events)

# %%
prob_head = 0.5

prob_two_heads = prob_head * prob_head

print("Probability of getting two heads in two tosses is:-", prob_two_heads)


#Task 5L Calculate the probability of rolling a 6 twice in a row with a six-sided die. Print the result.

prob_six = 1/6

prob_six_sided = prob_six * prob_six
print("Probability of getting six-sided die is:-", prob_six_sided)
# Out:
# Probability of getting two heads in two tosses is:- 0.25
# Probability of getting six-sided die is:- 0.027777777777777776

# %% [markdown]
# #Exercise 6: Dependent Events

# %%
#lets calculate the probability of drawing two aces without replacement from a deck of 52 cards
total_cards = 52
ace = 4

prob_first_aces = ace / total_cards

prob_second_aces = prob_first_aces * (ace-1) /(total_cards - 1)

prob = prob_first_aces + prob_second_aces

print("Probability of drawing two aces without replacement", prob)


#Task 6: Calculate the probability of drawing two red cards without replacement from a deck (26 red cards, 52 total). Print the result
# Out:
# Probability of drawing two aces without replacement 0.08144796380090498
