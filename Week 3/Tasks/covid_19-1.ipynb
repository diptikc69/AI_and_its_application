# %% [markdown]
# # Importing Libraries

# %%
# import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# from ydata_profiling import ProfileReport

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/Covid Data.csv')

# %%
#Creating a copy
df_copy = df.copy ()

# %%
#check columns, data types, and non-null counts.
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 21 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   USMER                 1048575 non-null  int64
#  1   MEDICAL_UNIT          1048575 non-null  int64
#  2   SEX                   1048575 non-null  int64
#  3   PATIENT_TYPE          1048575 non-null  int64
#  4   DATE_DIED             1048575 non-null  object
#  5   INTUBED               1048575 non-null  int64
#  6   PNEUMONIA             1048575 non-null  int64
#  7   AGE                   1048575 non-null  int64
#  8   PREGNANT              1048575 non-null  int64
#  9   DIABETES              1048575 non-null  int64
#  10  COPD                  1048575 non-null  int64
#  11  ASTHMA                1048575 non-null  int64
#  12  INMSUPR               1048575 non-null  int64
#  13  HIPERTENSION          1048575 non-null  int64
# ...

# %%
#df.head() method le first 5 rows lai print garxa
df_copy.head()
# Out:
#    USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  PNEUMONIA  \
# 0      2             1    1             1  03/05/2020       97          1
# 1      2             1    2             1  03/06/2020       97          1
# 2      2             1    2             2  09/06/2020        1          2
# 3      2             1    1             1  12/06/2020       97          2
# 4      2             1    2             1  21/06/2020       97          2
#
#    AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  HIPERTENSION  OTHER_DISEASE  \
# 0   65         2         2  ...       2        2             1              2
# 1   72        97         2  ...       2        2             1              2
# 2   55        97         1  ...       2        2             2              2
# 3   53         2         2  ...       2        2             2              2
# 4   68        97         1  ...       2        2             1              2
#
# ...

# %%
# df.describe() for numerical feature statistics(mean,median,mode)
df_copy.describe()
# Out:
#               USMER  MEDICAL_UNIT           SEX  PATIENT_TYPE       INTUBED  \
# count  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06
# mean   1.632194e+00  8.980565e+00  1.499259e+00  1.190765e+00  7.952288e+01
# std    4.822084e-01  3.723278e+00  4.999997e-01  3.929041e-01  3.686889e+01
# min    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    1.000000e+00  4.000000e+00  1.000000e+00  1.000000e+00  9.700000e+01
# 50%    2.000000e+00  1.200000e+01  1.000000e+00  1.000000e+00  9.700000e+01
# 75%    2.000000e+00  1.200000e+01  2.000000e+00  1.000000e+00  9.700000e+01
# max    2.000000e+00  1.300000e+01  2.000000e+00  2.000000e+00  9.900000e+01
#
#           PNEUMONIA           AGE      PREGNANT      DIABETES          COPD  \
# count  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06
# mean   3.346831e+00  4.179410e+01  4.976558e+01  2.186404e+00  2.260569e+00
# ...

# %% [markdown]
# # **Data Quality Checks**

# %%
df.isnull().sum()
# Out:
# USMER                   0
# MEDICAL_UNIT            0
# SEX                     0
# PATIENT_TYPE            0
# DATE_DIED               0
# INTUBED                 0
# PNEUMONIA               0
# AGE                     0
# PREGNANT                0
# DIABETES                0
# COPD                    0
# ASTHMA                  0
# INMSUPR                 0
# HIPERTENSION            0
# OTHER_DISEASE           0
# CARDIOVASCULAR          0
# OBESITY                 0
# RENAL_CHRONIC           0
# TOBACCO                 0
# CLASIFFICATION_FINAL    0
# ICU                     0
# dtype: int64

# %%
#missing value list
# df.isnull().sum()
df_copy.dropna(inplace=True)
df_copy.isnull().sum()
# Out:
# USMER                   0
# MEDICAL_UNIT            0
# SEX                     0
# PATIENT_TYPE            0
# DATE_DIED               0
# INTUBED                 0
# PNEUMONIA               0
# AGE                     0
# PREGNANT                0
# DIABETES                0
# COPD                    0
# ASTHMA                  0
# INMSUPR                 0
# HIPERTENSION            0
# OTHER_DISEASE           0
# CARDIOVASCULAR          0
# OBESITY                 0
# RENAL_CHRONIC           0
# TOBACCO                 0
# CLASIFFICATION_FINAL    0
# ICU                     0
# dtype: int64

# %%
df_copy.duplicated().sum()
#
# Out:
# np.int64(812049)

# %%
df_copy.drop_duplicates(inplace = True) #removing duplicates

# %%
df_copy
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  \
# 0            2             1    1             1  03/05/2020       97
# 1            2             1    2             1  03/06/2020       97
# 2            2             1    2             2  09/06/2020        1
# 3            2             1    1             1  12/06/2020       97
# 4            2             1    2             1  21/06/2020       97
# ...        ...           ...  ...           ...         ...      ...
# 1048568      1            13    2             1  9999-99-99       97
# 1048569      1            13    1             2  9999-99-99        2
# 1048571      1            13    2             2  9999-99-99        2
# 1048572      2            13    2             1  9999-99-99       97
# 1048574      2            13    2             1  9999-99-99       97
#
#          PNEUMONIA  AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  \
# 0                1   65         2         2  ...       2        2
# ...

# %%
#df.nunique()` counts the **number of unique (non-duplicate) values** in **each column** of the DataFrame `df`.
print("Unique Values:\n",df.nunique())

#Sums up the total number of unique values across all columns.
print("\nTotal Unique Values:",df.nunique().sum())

#how many times each unique value appears** in the `"sepalwidthcm"` column.
print("\nValues in Legendary Column:\n",df["MEDICAL_UNIT"].value_counts())
# Out:
# Unique Values:
#  USMER                     2
# MEDICAL_UNIT             13
# SEX                       2
# PATIENT_TYPE              2
# DATE_DIED               401
# INTUBED                   4
# PNEUMONIA                 3
# AGE                     121
# PREGNANT                  4
# DIABETES                  3
# COPD                      3
# ASTHMA                    3
# INMSUPR                   3
# HIPERTENSION              3
# OTHER_DISEASE             3
# CARDIOVASCULAR            3
# OBESITY                   3
# RENAL_CHRONIC             3
# TOBACCO                   3
# CLASIFFICATION_FINAL      7
# ICU                       4
# dtype: int64
#
# Total Unique Values: 593
#
# Values in Legendary Column:
#  MEDICAL_UNIT
# 12    602995
# 4     314405
# 6      40584
# 9      38116
# 3      19175
# 8      10399
# 10      7873
# 5       7244
# 11      5577
# 13       996
# 7        891
# 2        169
# 1        151
# Name: count, dtype: int64

# %%
# Example with df_copy
print("Before:\n\n", df_copy.dtypes)

df_copy["SEX"] = df_copy["SEX"].astype("category")

print("\n\nAfter:\n\n", df_copy.dtypes)
# Out:
# Before:
#
#  USMER                    int64
# MEDICAL_UNIT             int64
# SEX                      int64
# PATIENT_TYPE             int64
# DATE_DIED               object
# INTUBED                  int64
# PNEUMONIA                int64
# AGE                      int64
# PREGNANT                 int64
# DIABETES                 int64
# COPD                     int64
# ASTHMA                   int64
# INMSUPR                  int64
# HIPERTENSION             int64
# OTHER_DISEASE            int64
# CARDIOVASCULAR           int64
# OBESITY                  int64
# RENAL_CHRONIC            int64
# TOBACCO                  int64
# CLASIFFICATION_FINAL     int64
# ICU                      int64
# dtype: object
#
#
# After:
#
#  USMER                      int64
# MEDICAL_UNIT               int64
# SEX                     category
# PATIENT_TYPE               int64
# DATE_DIED                 object
# INTUBED                    int64
# PNEUMONIA                  int64
# ...

# %%
df_copy['DATE_DIED'] = df_copy['DATE_DIED'].fillna('Not Died')
df_copy
# Out:
#          USMER  MEDICAL_UNIT SEX  PATIENT_TYPE   DATE_DIED  INTUBED  \
# 0            2             1   1             1  03/05/2020       97
# 1            2             1   2             1  03/06/2020       97
# 2            2             1   2             2  09/06/2020        1
# 3            2             1   1             1  12/06/2020       97
# 4            2             1   2             1  21/06/2020       97
# ...        ...           ...  ..           ...         ...      ...
# 1048568      1            13   2             1  9999-99-99       97
# 1048569      1            13   1             2  9999-99-99        2
# 1048571      1            13   2             2  9999-99-99        2
# 1048572      2            13   2             1  9999-99-99       97
# 1048574      2            13   2             1  9999-99-99       97
#
#          PNEUMONIA  AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  \
# 0                1   65         2         2  ...       2        2
# ...

# %% [markdown]
# # **Visualization**

# %%
# plt.figure(figsize=(12, 6))
# sns.countplot(x='AGE', data=df_copy)
# plt.title("COVID Age Distribution")

# # Rotate x-axis labels by 90 degrees for better readability
# plt.xticks(rotation=5)
# plt.show()

# %%
#Histrogram Plot
sns.histplot(df_copy["AGE"], kde=True)
plt.title("Distribution of Age in COVID Dataset")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# %%
# # Plotting bar chart for first 20 records to avoid clutter
# plt.figure(figsize=(12, 6))
# sns.barplot(x=df_copy.index[:20], y=df_copy["AGE"].head(20))

# plt.xlabel("Index")
# plt.ylabel("Age")
# plt.title("Age Distribution by Record Index (First 20 Samples)")
# plt.xticks(rotation=90)
# plt.show()

# %%
#Heatmap
# केवल संख्यात्मक स्तम्भहरू (numerical columns) को कोरिलेसन हेर्ने
correlation_matrix = df.select_dtypes(include=['number']).corr()

# correlation matrix fig
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")


# Label Encoding: convert sting into the number
from sklearn.preprocessing import LabelEncoder

#  (Title)
plt.title("Interrelationship of features (Correlation)")
plt.show()

# %%
#create a new column named IS_DEAD (1= dead and 0=not dead)
df['IS_DEAD'] = df['DATE_DIED'].apply(lambda x: 0 if x == '9999-99-99' else 1)

#select only numeric columns(int (like: 0, 1, 25, 100) , float (like: 3.14, 98.6))
selected_cols = df[['ICU', 'IS_DEAD']]

#Draw the correlation matrix
correlation_matrix = selected_cols.corr()

# Draw a figure
plt.figure(figsize=(6, 4))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")

# title
plt.title("Correlation Matrix of ICU and IS_DEAD")
plt.show()

# %% [markdown]
# +1 Perfect positive relation(The more people go to the ICU, the more death occur)
#
# -1 Perfect negative relation (The more people go to ICU, the less death occur)

# %%
##Boxplot
# Clean column names
df_copy.columns = df_copy.columns.str.strip()

# Select a few numeric columns relevant for boxplot
selected_columns = ["AGE", "INTUBED", "ICU", "CLASIFFICATION_FINAL"]

# Create a new DataFrame for plotting
df_plot = df_copy[selected_columns]

# Plot boxplot
plt.figure(figsize=(10, 6))
sns.boxplot(data=df_plot, palette="Set3")

# Set labels and title
plt.title("Boxplot of COVID-19 Dataset Features", fontsize=16)
plt.xlabel("Features", fontsize=12)
plt.ylabel("Values", fontsize=12)

# Rotate x-axis labels
plt.xticks(rotation=45)

# Show plot
plt.tight_layout()
plt.show()

# %%
# KDE Plot for AGE
plt.figure(figsize=(8, 5))
sns.kdeplot(df_copy["AGE"], fill=True, color='blue')
plt.title("KDE Plot of Age")
plt.xlabel("Age")
plt.ylabel("Density")
plt.tight_layout()
plt.show()

# KDE Plot for CLASIFFICATION_FINAL
plt.figure(figsize=(8, 5))
sns.kdeplot(df_copy["CLASIFFICATION_FINAL"], fill=True, color='green')
plt.title("KDE Plot of Classification Final")
plt.xlabel("Classification")
plt.ylabel("Density")
plt.tight_layout()
plt.show()

# KDE Plot for INTUBED
plt.figure(figsize=(8, 5))
sns.kdeplot(df_copy["INTUBED"], fill=True, color='orange')
plt.title("KDE Plot of Intubed")
plt.xlabel("Intubed")
plt.ylabel("Density")
plt.tight_layout()
plt.show()

# KDE Plot for ICU
plt.figure(figsize=(8, 5))
sns.kdeplot(df_copy["ICU"], fill=True, color='red')
plt.title("KDE Plot of ICU")
plt.xlabel("ICU")
plt.ylabel("Density")
plt.tight_layout()
plt.show()

# %% [markdown]
# # **Outlier Detection and Handling**

# %%
# Drop 'Id' column if it exists
df_copy = df.drop('Id', axis=1).copy() if 'Id' in df.columns else df.copy()

# Clean column names
df_copy.columns = df_copy.columns.str.strip()

# Detect and remove outliers using IQR for each numeric column
for column in df_copy.select_dtypes(include='number').columns:
    q1 = df_copy[column].quantile(0.25)
    q3 = df_copy[column].quantile(0.75)
    iqr = q3 - q1
    lower_limit = q1 - 1.5 * iqr
    upper_limit = q3 + 1.5 * iqr
    df_copy = df_copy[(df_copy[column] >= lower_limit) & (df_copy[column] <= upper_limit)]

# Select a few numeric columns relevant for boxplot
selected_columns = ["AGE"]
df_plot = df_copy[selected_columns]

# Plot boxplot after removing outliers
plt.figure(figsize=(10, 6))
sns.boxplot(data=df_plot, palette="Set3")

# Set labels and title
plt.title("Boxplot of COVID-19 Dataset Features (Outliers Removed)", fontsize=16)
plt.xlabel("Features", fontsize=12)
plt.ylabel("Values", fontsize=12)
plt.xticks(rotation=45)

# Show plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # **Features Engineering**

# %%
# Standardize AGE column (Z-score)
df_copy["Age_Zscore"] = (df_copy["AGE"] - df_copy["AGE"].mean()) / df_copy["AGE"].std()

# %%
df_copy["ICU_Zscore"] = (df_copy["ICU"] - df_copy["ICU"].mean()) / df_copy["ICU"].std()

# %%
df_copy['DATE_DIED'] = pd.to_datetime(df_copy['DATE_DIED'], errors='coerce')
df_copy
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE  DATE_DIED  INTUBED  \
# 3            2             1    1             1 2020-12-06       97
# 6            2             1    1             1        NaT       97
# 10           2             1    1             1        NaT       97
# 13           2             1    2             1        NaT       97
# 15           2             1    1             1        NaT       97
# ...        ...           ...  ...           ...        ...      ...
# 1048565      1            13    1             1        NaT       97
# 1048570      2            13    2             1        NaT       97
# 1048572      2            13    2             1        NaT       97
# 1048573      2            13    2             1        NaT       97
# 1048574      2            13    2             1        NaT       97
#
#          PNEUMONIA  AGE  PREGNANT  DIABETES  ...  OTHER_DISEASE  \
# 3                2   53         2         2  ...              2
# ...

# %% [markdown]
# # Regression dataset

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# Split the data into training and testing parts (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# Create a logistic regression model and train it on the training data
model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)

# Check the model's accuracy
from sklearn.metrics import accuracy_score
y_pred = model.predict(X_test)  # Make predictions on the test data
print("Accuracy:", accuracy_score(y_test, y_pred))  # Print the accuracy score
# Out:
# Accuracy: 0.924507069117612

# %%
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

# Model's predictions on the test data
y_pred = model.predict(X_test)

# Show the confusion matrix (tells which predictions were right or wrong)
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))

# Show detailed report (includes precision, recall, and F1-score)
print("Classification Report:\n", classification_report(y_test, y_pred))

# Show accuracy score (percentage of total correct predictions)
print("Accuracy Score:", accuracy_score(y_test, y_pred))
# Out:
# Confusion Matrix:
#  [[192892   1396]
#  [ 14436    991]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96    194288
#            1       0.42      0.06      0.11     15427
#
#     accuracy                           0.92    209715
#    macro avg       0.67      0.53      0.54    209715
# weighted avg       0.89      0.92      0.90    209715
#
# Accuracy Score: 0.924507069117612

# %% [markdown]
# 'Positive' भन्यो (जस्तै – मरेको), तिनीहरूमध्ये कति साँचोमा 'Positive' थिए वास्तवमा 'Positive' (मरेका) भएका मध्ये कति जनालाई मोडेलले सही रूपमा पत्ता लगायो Precision र Recall को balance (average)।

# %%
from sklearn.metrics import confusion_matrix


# Heatmap मा देखाउौं
# Example: True and predicted values
y_true = [0, 1, 0, 1, 0, 1, 1, 0]
y_pred = [0, 1, 0, 0, 0, 1, 1, 1]

# Generate the confusion matrix
cm = confusion_matrix(y_true, y_pred)

# Plot the heatmap
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix Heatmap')
plt.show()

# %% [markdown]
# #**Summarized** Findings – Covid Dataset**

# %% [markdown]
# 1. The dataset contains no missing values or duplicate records after initial cleaning.
#
# 2. Most patient ages fall within a normal range, with a mean around the mid-40s.
#
# 3. Outliers in numeric features such as AGE, INTUBED, ICU, and CLASIFFICATION_FINAL were detected and removed using the IQR method.
#
# 4. A majority of patients were not intubated or admitted to the ICU, indicating that severe cases were less frequent.
